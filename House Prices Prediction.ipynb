# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# Loading dataset
rawDf = pd.read_csv("D:\\Ujjawal\\Downloads\\PropertyPrice_Data.csv")
rawDf
# Out:
#         Id Road_Type Property_Shape House_Type  House_Condition  \
# 0        1     Paved            Reg       1Fam                5
# 1        2     Paved            Reg       1Fam                8
# 2        3     Paved            IR1       1Fam                5
# 3        4     Paved            IR1       1Fam                5
# 4        5     Paved            IR1       1Fam                5
# ...    ...       ...            ...        ...              ...
# 1454  1455     Paved            Reg       1Fam                5
# 1455  1456     Paved            Reg       1Fam                5
# 1456  1457     Paved            Reg       1Fam                6
# 1457  1458     Paved            Reg       1Fam                9
# 1458  1459     Paved            Reg       1Fam                6
#
#       Construction_Year  Remodel_Year  BsmtFinSF1  Total_Basement_Area  \
# 0                  2003          2003         706                  856
# ...

# %%
# Shape
rawDf.shape
# Out:
# (1459, 26)

# %%
# Dimensions
print("No. of rows: ",rawDf.shape[0])
print("No. of columns: ", rawDf.shape[1])
# Out:
# No. of rows:  1459
# No. of columns:  26

# %%
# Statistical Description
rawDf.describe()
# Out:
#                 Id  House_Condition  Construction_Year  Remodel_Year  \
# count  1459.000000      1459.000000        1459.000000   1459.000000
# mean    730.000000         5.575051        1971.272104   1984.879369
# std     421.321334         1.113125          30.212814     20.645927
# min       1.000000         1.000000        1872.000000   1950.000000
# 25%     365.500000         5.000000        1954.000000   1967.000000
# 50%     730.000000         5.000000        1973.000000   1994.000000
# 75%    1094.500000         6.000000        2000.000000   2004.000000
# max    1459.000000         9.000000        2010.000000   2010.000000
#
#         BsmtFinSF1  Total_Basement_Area  First_Floor_Area  Second_Floor_Area  \
# count  1459.000000          1459.000000       1459.000000        1459.000000
# mean    443.374914          1057.293352       1162.562714         347.230295
# std     456.142186           438.824912        386.712553         436.583480
# ...

# %%
# Statistical Description of all columns
rawDf.describe(include='all')
# Out:
#                  Id Road_Type Property_Shape House_Type  House_Condition  \
# count   1459.000000      1459           1459       1459      1459.000000
# unique          NaN         2              4          5              NaN
# top             NaN     Paved            Reg       1Fam              NaN
# freq            NaN      1453            924       1219              NaN
# mean     730.000000       NaN            NaN        NaN         5.575051
# std      421.321334       NaN            NaN        NaN         1.113125
# min        1.000000       NaN            NaN        NaN         1.000000
# 25%      365.500000       NaN            NaN        NaN         5.000000
# 50%      730.000000       NaN            NaN        NaN         5.000000
# 75%     1094.500000       NaN            NaN        NaN         6.000000
# max     1459.000000       NaN            NaN        NaN         9.000000
#
#         Construction_Year  Remodel_Year   BsmtFinSF1  Total_Basement_Area  \
# ...

# %%
# information of the dataset
rawDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 26 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Id                         1459 non-null   int64
#  1   Road_Type                  1459 non-null   object
#  2   Property_Shape             1459 non-null   object
#  3   House_Type                 1459 non-null   object
#  4   House_Condition            1459 non-null   int64
#  5   Construction_Year          1459 non-null   int64
#  6   Remodel_Year               1459 non-null   int64
#  7   BsmtFinSF1                 1459 non-null   int64
#  8   Total_Basement_Area        1459 non-null   int64
#  9   Air_Conditioning           1459 non-null   object
#  10  First_Floor_Area           1459 non-null   int64
#  11  Second_Floor_Area          1459 non-null   int64
#  12  LowQualFinSF               1459 non-null   int64
# ...

# %%
# 20 continuous columns and 6 categorical columns

# %%
# Columns info
rawDf.columns
# Out:
# Index(['Id', 'Road_Type', 'Property_Shape', 'House_Type', 'House_Condition',
#        'Construction_Year', 'Remodel_Year', 'BsmtFinSF1',
#        'Total_Basement_Area', 'Air_Conditioning', 'First_Floor_Area',
#        'Second_Floor_Area', 'LowQualFinSF', 'Underground_Full_Bathroom',
#        'Full_Bathroom_Above_Grade', 'Bedroom_Above_Grade', 'Kitchen_Quality',
#        'Rooms_Above_Grade', 'Fireplaces', 'Garage', 'Garage_Built_Year',
#        'Garage_Area', 'Pool_Area', 'Miscellaneous_Value', 'Year_Sold',
#        'Sale_Price'],
#       dtype='object')

# %%
# We have one ID column

# %%
# Removing ID column
rawDf.drop('Id', axis=1, inplace=True)

# %%
rawDf.columns
# Out:
# Index(['Road_Type', 'Property_Shape', 'House_Type', 'House_Condition',
#        'Construction_Year', 'Remodel_Year', 'BsmtFinSF1',
#        'Total_Basement_Area', 'Air_Conditioning', 'First_Floor_Area',
#        'Second_Floor_Area', 'LowQualFinSF', 'Underground_Full_Bathroom',
#        'Full_Bathroom_Above_Grade', 'Bedroom_Above_Grade', 'Kitchen_Quality',
#        'Rooms_Above_Grade', 'Fireplaces', 'Garage', 'Garage_Built_Year',
#        'Garage_Area', 'Pool_Area', 'Miscellaneous_Value', 'Year_Sold',
#        'Sale_Price'],
#       dtype='object')

# %% [markdown]
# Missing Values Imputation

# %%
# Checking Missing Values
rawDf.isna().sum()
# Out:
# Road_Type                     0
# Property_Shape                0
# House_Type                    0
# House_Condition               0
# Construction_Year             0
# Remodel_Year                  0
# BsmtFinSF1                    0
# Total_Basement_Area           0
# Air_Conditioning              0
# First_Floor_Area              0
# Second_Floor_Area             0
# LowQualFinSF                  0
# Underground_Full_Bathroom     0
# Full_Bathroom_Above_Grade     0
# Bedroom_Above_Grade           0
# Kitchen_Quality               0
# Rooms_Above_Grade             0
# Fireplaces                    0
# Garage                       81
# Garage_Built_Year            81
# Garage_Area                   0
# Pool_Area                     0
# Miscellaneous_Value           0
# Year_Sold                     0
# Sale_Price                    0
# dtype: int64

# %%
# Missing values in 2 columns - Garage and Garage_Built_Year

# %%
# Impuation of Missing Values
# Garage

# %%
rawDf['Garage'].dtypes
# Out:
# dtype('O')

# %%
# Categorical column

# %%
tempMode = rawDf['Garage'].mode()[0]
tempMode
# Out:
# 'Attchd'

# %%
rawDf['Garage'].fillna(tempMode,inplace=True)

# %%
rawDf.isna().sum()
# Out:
# Road_Type                     0
# Property_Shape                0
# House_Type                    0
# House_Condition               0
# Construction_Year             0
# Remodel_Year                  0
# BsmtFinSF1                    0
# Total_Basement_Area           0
# Air_Conditioning              0
# First_Floor_Area              0
# Second_Floor_Area             0
# LowQualFinSF                  0
# Underground_Full_Bathroom     0
# Full_Bathroom_Above_Grade     0
# Bedroom_Above_Grade           0
# Kitchen_Quality               0
# Rooms_Above_Grade             0
# Fireplaces                    0
# Garage                        0
# Garage_Built_Year            81
# Garage_Area                   0
# Pool_Area                     0
# Miscellaneous_Value           0
# Year_Sold                     0
# Sale_Price                    0
# dtype: int64

# %%
# Garage_Built_Year

# %%
rawDf['Garage_Built_Year'].dtypes
# Out:
# dtype('float64')

# %%
# Continuous column

# %%
tempMedian = rawDf['Garage_Built_Year'].median()

# %%
tempMedian
# Out:
# 1980.0

# %%
rawDf['Garage_Built_Year'].fillna(tempMedian, inplace=True)

# %%
rawDf.isna().sum()
# Out:
# Road_Type                    0
# Property_Shape               0
# House_Type                   0
# House_Condition              0
# Construction_Year            0
# Remodel_Year                 0
# BsmtFinSF1                   0
# Total_Basement_Area          0
# Air_Conditioning             0
# First_Floor_Area             0
# Second_Floor_Area            0
# LowQualFinSF                 0
# Underground_Full_Bathroom    0
# Full_Bathroom_Above_Grade    0
# Bedroom_Above_Grade          0
# Kitchen_Quality              0
# Rooms_Above_Grade            0
# Fireplaces                   0
# Garage                       0
# Garage_Built_Year            0
# Garage_Area                  0
# Pool_Area                    0
# Miscellaneous_Value          0
# Year_Sold                    0
# Sale_Price                   0
# dtype: int64

# %%
# All the missing values have been successfully imputed

# %% [markdown]
# # UNIVARIATE ANALYSIS

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %% [markdown]
# Road Type

# %%
rawDf['Road_Type'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
# Almost all Houses have paved roads in its surroundings

# %% [markdown]
# Property Shape

# %%
rawDf['Property_Shape'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
# More than 60% houses belong to regular property shape category

# %% [markdown]
# House Type

# %%
rawDf['House_Type'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
# Majority houses which are on sale are for ! family or nuclear family

# %% [markdown]
# House Condition

# %%
rawDf['House_Condition'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
# Houses with ratings of 5,6 and 7 on the basis of conditions 
# constitute more than 80% of total

# %% [markdown]
# Construction Year

# %%
rawDf['Construction_Year'].value_counts()
# Out:
# 2006    67
# 2005    64
# 2004    54
# 2007    49
# 2003    45
#         ..
# 1875     1
# 1911     1
# 1917     1
# 1872     1
# 1905     1
# Name: Construction_Year, Length: 112, dtype: int64

# %%
top_10 = rawDf['Construction_Year'].value_counts().nlargest(10)
last_10 = rawDf['Construction_Year'].value_counts().nsmallest(10)

# %%
# Visualizing top 10 values
plt.figure(figsize=(10,6))
top_10.plot(kind="bar")
plt.title("Most Common Construction Years")
plt.show()

# %%
# 2003 to 2006 are the most common construction year with 2006 at the top

# %%
# Visualizing least common construction years
plt.figure(figsize=(10,6))
last_10.plot(kind="bar")
plt.title("Least Common Construction Years")
plt.show()

# %%
# There are many construction years with only 1 house constructed

# %% [markdown]
# Remodel Year

# %%
rawDf['Remodel_Year'].value_counts()
# Out:
# 1950    178
# 2006     97
# 2007     76
# 2005     73
# 2004     62
#        ...
# 2010      6
# 1986      5
# 1952      5
# 1983      5
# 1951      4
# Name: Remodel_Year, Length: 61, dtype: int64

# %%
top_10 = rawDf['Remodel_Year'].value_counts().nlargest(10)
last_10 = rawDf['Remodel_Year'].value_counts().nsmallest(10)

# %%
# Visualizing the top 10 values
plt.figure(figsize=(10,6))
top_10.plot(kind="bar")
plt.title("Most Common Remodel Years")
plt.show()

# %%
# 1950 is the most common remodel year followed by 2006 and 2007

# %%
# Visualizing the least 10 values
plt.figure(figsize=(10,6))
last_10.plot(kind="bar")
plt.title("Least Common Remodel Years")
plt.show()

# %%
# 1951 is the least common remodel year

# %% [markdown]
# BsmtFinSF1 -- Type 1 finished square feet

# %%
rawDf['BsmtFinSF1'].value_counts()
# Out:
# 0       467
# 24       12
# 16        9
# 686       5
# 662       5
#        ...
# 1338      1
# 1324      1
# 1460      1
# 328       1
# 49        1
# Name: BsmtFinSF1, Length: 636, dtype: int64

# %%
from collections import Counter
cf=[]
# Define ranges
ranges = [(0,500),(500,1000),(1000,1500),(1500,2000),(2000,2500),(2500,3000),(3000,3500),(3500,4000),(4000,4500),
         (4500,5000),(5000,5500),(5500,6000)]

# Calculate sum of frequencies for each range
for start, end in ranges:
    sum_frequency = sum(count for value, count in Counter(rawDf['BsmtFinSF1']).items() if start <= value <= end)
    cf.append(sum_frequency)

# %%
cf
# Out:
# [847, 437, 159, 17, 3, 0, 0, 0, 0, 0, 0, 1]

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=["0-500","500-1000","1000-1500","1500-2000","2000-2500","2500-3000","3000-3500","3500-4000","4000-4500",
              "4500-5000","5000-5500","5500-6000"], y=cf)
plt.title("Basement Finished Square Feet")
plt.show()

# %%
# BsmtFinSF1 from 0 to 1500 occupies more than 95% of the total

# %% [markdown]
# Total Basement Area

# %%
rawDf['Total_Basement_Area'].value_counts()
# Out:
# 0       37
# 864     35
# 672     17
# 912     15
# 1040    14
#         ..
# 1838     1
# 1581     1
# 707      1
# 611      1
# 1542     1
# Name: Total_Basement_Area, Length: 721, dtype: int64

# %%
from collections import Counter
cf1=[]
# Define ranges
ranges = [(0,500),(500,1000),(1000,1500),(1500,2000),(2000,2500),(2500,3000),(3000,3500),(3500,4000),(4000,4500),
         (4500,5000),(5000,5500),(5500,6000),(6000,6500)]

# Calculate sum of frequencies for each range
for start, end in ranges:
    sum_frequency = sum(count for value, count in Counter(rawDf['Total_Basement_Area']).items() if start <= value <= end)
    cf1.append(sum_frequency)

# %%
cf1
# Out:
# [71, 672, 512, 175, 24, 2, 4, 0, 0, 0, 0, 0, 1]

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=["0-500","500-1000","1000-1500","1500-2000","2000-2500","2500-3000","3000-3500","3500-4000","4000-4500",
              "4500-5000","5000-5500","5500-6000","6000-6500"], y=cf1)
plt.title("Total Basement Area")
plt.show()

# %%
# Basement Area of 500 to 1000 sq mtrs are most common, followed by 1000 to 1500 sq mtrs

# %% [markdown]
# Air Conditioning

# %%
rawDf['Air_Conditioning'].value_counts()
# Out:
# Y    1364
# N      95
# Name: Air_Conditioning, dtype: int64

# %%
plt.figure(figsize=(5,5))
plt.pie(rawDf['Air_Conditioning'].value_counts(), labels=['Yes',
                'No'], autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2056370f280>,
# ...
#  [Text(-1.0770657879068475, 0.22344862613272426, 'Yes'),
#   Text(1.0770658035974223, -0.22344855050109147, 'No')],
#  [Text(-0.5874904297673713, 0.12188106879966776, '93.5%'),
#   Text(0.5874904383258667, -0.12188102754604987, '6.5%')])

# %%
# More than 90% of the houses have air conditioning

# %% [markdown]
# First Floor Area

# %%
rawDf['First_Floor_Area'].max()
# Out:
# 4692

# %%
cf2=[]
# Define ranges
ranges = [(0,500),(500,1000),(1000,1500),(1500,2000),(2000,2500),(2500,3000),(3000,3500),(3500,4000),(4000,4500),
         (4500,5000)]

# Calculate sum of frequencies for each range
for start, end in ranges:
    sum_frequency = sum(count for value, count in Counter(rawDf['First_Floor_Area']).items() if start <= value <= end)
    cf2.append(sum_frequency)

# %%
cf2
# Out:
# [12, 572, 602, 236, 35, 4, 2, 0, 0, 1]

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=["0-500","500-1000","1000-1500","1500-2000","2000-2500","2500-3000","3000-3500","3500-4000","4000-4500",
              "4500-5000"], y=cf2)
plt.title("First Floor Area")
plt.show()

# %%
# First floor areas ranging between 1000 and 1500 sq mtr are the
# most common followed by 500-1000

# %% [markdown]
# Second Floor Area

# %%
rawDf['Second_Floor_Area'].max()
# Out:
# 2065

# %%
cf3=[]
# Define ranges
ranges = [(0,500),(500,1000),(1000,1500),(1500,2000),(2000,2500)]

# Calculate sum of frequencies for each range
for start, end in ranges:
    sum_frequency = sum(count for value, count in 
     Counter(rawDf['Second_Floor_Area']).items() 
                        if start <= value <= end)
    cf3.append(sum_frequency)

# %%
cf3
# Out:
# [888, 447, 114, 10, 1]

# %%
plt.figure(figsize=(8,6))
sns.barplot(x=["0-500","500-1000","1000-1500","1500-2000",
               "2000-2500"], y=cf3)
plt.title("Second Floor Area")
plt.show()

# %%
# Second Floor Area ranging between 0 to 500 are the most common
# followed by 500-1000

# %% [markdown]
# Low Quality Finished Square Feets

# %%
rawDf['LowQualFinSF'].value_counts()
# Out:
# 0      1433
# 80        3
# 360       2
# 205       1
# 479       1
# 397       1
# 514       1
# 120       1
# 481       1
# 232       1
# 53        1
# 515       1
# 156       1
# 473       1
# 420       1
# 390       1
# 371       1
# 392       1
# 144       1
# 572       1
# 528       1
# 234       1
# 513       1
# 384       1
# Name: LowQualFinSF, dtype: int64

# %%
cf4=[]
# Define ranges
ranges = [(0,100),(100,200),(200,300),(300,400),(400,500),(500,600)]

# Calculate sum of frequencies for each range
for start, end in ranges:
    sum_frequency = sum(count for value, count in 
     Counter(rawDf['LowQualFinSF']).items() 
                        if start <= value <= end)
    cf4.append(sum_frequency)

# %%
cf4
# Out:
# [1437, 3, 3, 7, 4, 5]

# %%
plt.figure(figsize=(8,6))
sns.barplot(x=["0-100","100-200","200-300","300-400","400-500",
              "500-600"], y=cf4)
plt.title("Low Quality Finished Square Feet")
plt.show()

# %%
# Almost all houses' LowQualFinSF ranges from 0 to 100

# %% [markdown]
# Underground Full Bathroom

# %%
rawDf['Underground_Full_Bathroom'].value_counts()
# Out:
# 0    856
# 1    587
# 2     15
# 3      1
# Name: Underground_Full_Bathroom, dtype: int64

# %%
plt.figure(figsize=(7,6))
plt.pie(rawDf['Underground_Full_Bathroom'].value_counts(),
        labels=['0','1','2','3'], autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x205620ddab0>,
# ...
#  [Text(-0.2959335361681644, 1.0594448273369435, '0'),
#   Text(0.2592652260559264, -1.0690096082627927, '1'),
#   Text(1.099263118785331, -0.04025662278864354, '2'),
#   Text(1.0999974503022611, -0.0023684021036170233, '3')],
#  [Text(-0.16141829245536238, 0.5778789967292418, '58.7%'),
#   Text(0.14141739603050527, -0.5830961499615233, '40.2%'),
#   Text(0.5995980647919987, -0.021958157884714655, '1.0%'),
#   Text(0.5999986092557787, -0.0012918556928820126, '0.1%')])

# %%
# Almost all houses either have no underground bathroom or have 1
# underground bathroom

# %% [markdown]
# Full Bathroom Above Grade

# %%
rawDf['Full_Bathroom_Above_Grade'].value_counts()
# Out:
# 2    768
# 1    649
# 3     33
# 0      9
# Name: Full_Bathroom_Above_Grade, dtype: int64

# %%
plt.figure(figsize=(7,6))
plt.pie(rawDf['Full_Bathroom_Above_Grade'].value_counts(),
        labels=['2','1','3','0'], autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x205636ad090>,
# ...
#  [Text(-0.09108572567375524, 1.0962223271665676, '2'),
#   Text(-0.008289952927343941, -1.0999687616839229, '1'),
#   Text(1.093373936643351, -0.12055469575682941, '3'),
#   Text(1.0997934512934278, -0.021315827267332867, '0')],
#  [Text(-0.04968312309477558, 0.5979394511817642, '52.6%'),
#   Text(-0.004521792505823967, -0.5999829609185033, '44.5%'),
#   Text(0.5963857836236459, -0.0657571067764524, '2.3%'),
#   Text(0.5998873370691423, -0.011626814873090655, '0.6%')])

# %%
# More than half of the houses have 2 full bathrooms, which is
# followed by 44.5% of the houses having 1 full bathroom

# %% [markdown]
# Bedroom Above Grade

# %%
rawDf['Bedroom_Above_Grade'].value_counts()
# Out:
# 3    803
# 2    358
# 4    213
# 1     50
# 5     21
# 6      7
# 0      6
# 8      1
# Name: Bedroom_Above_Grade, dtype: int64

# %%
rawDf['Bedroom_Above_Grade'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
# more than 50% of the houses have 3 bedrooms, followed by 2 and 4
# bedrooms respectively

# %% [markdown]
# Kitchen Quality

# %%
rawDf['Kitchen_Quality'].value_counts()
# Out:
# TA    734
# Gd    586
# Ex    100
# Fa     39
# Name: Kitchen_Quality, dtype: int64

# %%
plt.figure(figsize=(8,6))
plt.pie(rawDf['Kitchen_Quality'].value_counts(),
        labels=['Typical','Good','Excellent','Fair'], autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x205635e57e0>,
# ...
#  [Text(-0.010658415591276976, 1.0999483615957086, 'Typical'),
#   Text(-0.3141386388690615, -1.054190170495577, 'Good'),
#   Text(1.0201879241357628, -0.4113594528481913, 'Excellent'),
#   Text(1.0961236309358358, -0.09226584256397234, 'Fair')],
#  [Text(-0.005813681231605623, 0.5999718335976593, '50.3%'),
#   Text(-0.17134834847403352, -0.5750128202703146, '40.2%'),
#   Text(0.5564661404376887, -0.2243778833717407, '6.9%'),
#   Text(0.5978856168740921, -0.05032682321671218, '2.7%')])

# %%
# half of the kitchens are rated as fair, followed by Good

# %% [markdown]
# Rooms Above Grade

# %%
rawDf['Rooms_Above_Grade'].value_counts()
# Out:
# 6     401
# 7     329
# 5     275
# 8     187
# 4      97
# 9      75
# 10     47
# 11     18
# 3      17
# 12     11
# 2       1
# 14      1
# Name: Rooms_Above_Grade, dtype: int64

# %%
rawDf['Rooms_Above_Grade'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
# Houses with 6 to 7 rooms are the most common

# %% [markdown]
# Fire Places

# %%
rawDf['Fireplaces'].value_counts()
# Out:
# 0    689
# 1    650
# 2    115
# 3      5
# Name: Fireplaces, dtype: int64

# %%
plt.figure(figsize=(7,6))
plt.pie(rawDf['Fireplaces'].value_counts(),
        labels=['0','1','2','3'], autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x205634aa500>,
# ...
#  [Text(0.09580580263033897, 1.0958198976941222, '0'),
#   Text(-0.37263404587408017, -1.0349608049851522, '1'),
#   Text(1.060395132007161, -0.2925101092535366, '2'),
#   Text(1.0999362482402226, -0.01184271114329037, '3')],
#  [Text(0.052257710525639434, 0.5977199441967939, '47.2%'),
#   Text(-0.20325493411313464, -0.5645240754464466, '44.6%'),
#   Text(0.5783973447311787, -0.1595509686837472, '7.9%'),
#   Text(0.5999652263128487, -0.0064596606236129285, '0.3%')])

# %%
# 47% of the houses do not have fireplaces

# %% [markdown]
# Garage

# %%
rawDf['Garage'].value_counts()
# Out:
# Attchd     950
# Detchd     387
# BuiltIn     88
# Basment     19
# CarPort      9
# 2TFes        5
# 2Types       1
# Name: Garage, dtype: int64

# %%
rawDf['Garage'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
# More than 60% of houses have attached garages

# %% [markdown]
# Garage Built Year

# %%
rawDf['Garage_Built_Year'].value_counts()
# Out:
# 1980.0    96
# 2005.0    65
# 2006.0    59
# 2004.0    53
# 2003.0    50
#           ..
# 1900.0     1
# 1906.0     1
# 1908.0     1
# 1927.0     1
# 1933.0     1
# Name: Garage_Built_Year, Length: 97, dtype: int64

# %%
# Changing data type of this variable from float to int
rawDf['Garage_Built_Year']=rawDf['Garage_Built_Year'].astype(int)

# %%
rawDf['Garage_Built_Year'].value_counts()
# Out:
# 1980    96
# 2005    65
# 2006    59
# 2004    53
# 2003    50
#         ..
# 1900     1
# 1906     1
# 1908     1
# 1927     1
# 1933     1
# Name: Garage_Built_Year, Length: 97, dtype: int64

# %%
cf5=[]
# Define ranges
ranges = [(1900,1920),(1920,1940),(1940,1960),(1960,1980),
         (1980,2000),(2000,2020)]

# Calculate sum of frequencies for each range
for start, end in ranges:
    sum_frequency = sum(count for value, count in 
     Counter(rawDf['Garage_Built_Year']).items() 
                        if start <= value <= end)
    cf5.append(sum_frequency)

# %%
cf5
# Out:
# [31, 106, 225, 466, 399, 402]

# %%
plt.figure(figsize=(8,6))
sns.barplot(x=["1900-1920","1920-1940","1940-1960",
              "1960-1980","1980-2000","2000-2020"], y=cf5)
plt.title("Garage Built Year")
plt.show()

# %%
# Amost 75% of the garages in the houses are built after 1960

# %% [markdown]
# Garage Area

# %%
rawDf['Garage_Area'].value_counts()
# Out:
# 1085.793744    1
# 828.356830     1
# 168.162022     1
# 563.589911     1
# 395.512678     1
#               ..
# 153.523652     1
# 490.308093     1
# 99.337608      1
# 397.021370     1
# 603.143692     1
# Name: Garage_Area, Length: 1459, dtype: int64

# %%
# -129 to 1147

# %%
rawDf['Garage_Area']=rawDf['Garage_Area'].abs()

# %%
rawDf['Garage_Area'].max()
# Out:
# 1147.488093

# %%
cf6=[]
# Define ranges
ranges = [(1,200),(200,400),(400,600),(600,800),
         (800,1000),(1000,1200)]

# Calculate sum of frequencies for each range
for start, end in ranges:
    sum_frequency = sum(count for value, count in 
     Counter(rawDf['Garage_Area']).items() 
                        if start <= value <= end)
    cf6.append(sum_frequency)

# %%
cf6
# Out:
# [153, 378, 537, 304, 77, 10]

# %%
plt.figure(figsize=(8,6))
sns.barplot(x=["0-200","200-400","400-600",
              "600-800","800-1000","1000-1200"], y=cf6)
plt.title("Garage Area")
plt.show()

# %%
# Around 40% of the houses have garage areas rangng from 400 to
# 600 sq mtr

# %% [markdown]
# Pool Area

# %%
rawDf['Pool_Area'].value_counts()
# Out:
# 0      1452
# 512       1
# 648       1
# 576       1
# 555       1
# 480       1
# 519       1
# 738       1
# Name: Pool_Area, dtype: int64

# %%
rawDf['Pool_Area'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
# More than 99.5% of the houses don't have pool

# %% [markdown]
# Miscellaneous Value

# %%
rawDf['Miscellaneous_Value'].value_counts()
# Out:
# 0        1407
# 400        11
# 500         8
# 700         5
# 450         4
# 600         4
# 2000        4
# 1200        2
# 480         2
# 15500       1
# 800         1
# 350         1
# 3500        1
# 1300        1
# 54          1
# 620         1
# 560         1
# 1400        1
# 8300        1
# 1150        1
# 2500        1
# Name: Miscellaneous_Value, dtype: int64

# %%
top_10=rawDf['Miscellaneous_Value'].value_counts().nlargest(10)

# %%
plt.figure(figsize=(10,6))
top_10.plot(kind="bar")
plt.title("Miscellaneous Value")
plt.show()

# %%
# More than 95% houses do not have miscellaneous value

# %% [markdown]
# Years Sold

# %%
rawDf['Year_Sold'].value_counts()
# Out:
# 2009    338
# 2007    329
# 2006    314
# 2008    303
# 2010    175
# Name: Year_Sold, dtype: int64

# %%
rawDf['Year_Sold'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
# almost 25% of the houses were sold in 2009, followed by 2007 
# and 2006

# %% [markdown]
# Sale Price

# %%
rawDf['Sale_Price'].max()
# Out:
# 755000

# %%
cf7=[]
# Define ranges
ranges = [(0,100000),(100000,200000),(200000,300000),
         (300000,400000),(400000,500000),(500000,600000),
         (600000,700000),(700000,800000)]

# Calculate sum of frequencies for each range
for start, end in ranges:
    sum_frequency = sum(count for value, count in 
     Counter(rawDf['Sale_Price']).items() 
                        if start <= value <= end)
    cf7.append(sum_frequency)

# %%
cf7
# Out:
# [123, 918, 320, 87, 19, 5, 2, 2]

# %%
plt.figure(figsize=(8,6))
sns.barplot(x=["0-100k","100k-200k","200k-300k",
              "300k-400k","400k-500k","500k-600k",
              "600k-700k","700k-800k"], y=cf7)
plt.title("Sale Price")
plt.show()

# %%
# Around 65% of the houses have a selling price varying between
# $100k to $200k

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# Between continuous columns and dependent variable

# %%
ContVar = []
for i in rawDf.columns:
    if rawDf[i].dtypes!='O':
        ContVar.append(i)

# %%
ContVar
# Out:
# ['House_Condition',
#  'Construction_Year',
#  'Remodel_Year',
#  'BsmtFinSF1',
#  'Total_Basement_Area',
#  'First_Floor_Area',
#  'Second_Floor_Area',
#  'LowQualFinSF',
#  'Underground_Full_Bathroom',
#  'Full_Bathroom_Above_Grade',
#  'Bedroom_Above_Grade',
#  'Rooms_Above_Grade',
#  'Fireplaces',
#  'Garage_Built_Year',
#  'Garage_Area',
#  'Pool_Area',
#  'Miscellaneous_Value',
#  'Year_Sold',
#  'Sale_Price']

# %%
df = rawDf[ContVar]

# %%
corrDf = df.corr()

# %%
corrDf
# Out:
#                            House_Condition  Construction_Year  Remodel_Year  \
# House_Condition                   1.000000          -0.375953      0.074021
# Construction_Year                -0.375953           1.000000      0.592915
# Remodel_Year                      0.074021           0.592915      1.000000
# BsmtFinSF1                       -0.046466           0.249689      0.129082
# Total_Basement_Area              -0.171237           0.391550      0.291477
# First_Floor_Area                 -0.144276           0.282030      0.240620
# Second_Floor_Area                 0.029158           0.010197      0.139574
# LowQualFinSF                      0.025527          -0.183805     -0.062519
# Underground_Full_Bathroom        -0.055257           0.187838      0.120290
# Full_Bathroom_Above_Grade        -0.193961           0.468301      0.438667
# Bedroom_Above_Grade               0.012938          -0.070630     -0.040486
# ...

# %%
sns.heatmap(corrDf)
# Out:
# <Axes: >

# %%
# Sale Price is positively correlated with Construction Year, Remodel year, Total Basement area, First Floor Area,
# Full Bathroom Above grade and Rooms above grade

# %% [markdown]
# Between Categorical Variables and Dependent Variable

# %%
CatVar = rawDf.columns[rawDf.dtypes=='O']

# %%
CatVar
# Out:
# Index(['Road_Type', 'Property_Shape', 'House_Type', 'Air_Conditioning',
#        'Kitchen_Quality', 'Garage'],
#       dtype='object')

# %%
for i in CatVar:
    figure()
    sns.boxplot(x=rawDf[i],y=rawDf['Sale_Price'])

# %%
# Houses with paved roads have a higher sale price than those with gravel roads
# Property shape of IR2 have the highest median sale price, while property shape of IR1 and IR3 have highest price range
# Houses for 1 family have the highest price range
# Houses with air conditioning are expensive than those without it
# Houses with Excellent kitchens have highest price range
# Houses with Built-in Garages have the highest price range

# %% [markdown]
# Detailed analysis of Continuous variables and dependent variable

# %% [markdown]
# House Condition

# %%
sns.barplot(x=rawDf['House_Condition'], y=rawDf['Sale_Price'])
plt.xlabel("House Consition")
plt.ylabel("Sale Price")
plt.show()

# %%
# Houses with 9 rating are the most expensive ones, followed by the ones with 5 rating

# %% [markdown]
# So there is no relation between House Condition and Sale Price

# %% [markdown]
# Construction Year

# %%
sns.lineplot(x=rawDf['Construction_Year'], y=rawDf['Sale_Price'])
plt.xlabel("Construction Year")
plt.ylabel("Sale Price")
plt.show()

# %%
# Houses constructed after 2010 are the most expensive ones

# %% [markdown]
# There is a positive correlation between Construction Year and Sale Price

# %% [markdown]
# Remodel Year

# %%
sns.lineplot(x=rawDf['Remodel_Year'], y=rawDf['Sale_Price'])
plt.xlabel("Remodel Year")
plt.ylabel("Sale Price")
plt.show()

# %%
# Houses remodelled around 2010 are the most expensive ones

# %% [markdown]
# There is a positive correlation between Remodel Year and Sale Price

# %% [markdown]
# Basement Finished Square Feet

# %%
sns.scatterplot(x=rawDf['BsmtFinSF1'], y=rawDf['Sale_Price'])
plt.xlabel("Basement Finished SF")
plt.ylabel("Sale Price")
plt.show()

# %% [markdown]
# There is no correlation between BsmtFinSF1 and Sale Price as house with Basement of 5000 square feet has lower price than most of the houses with no basement.

# %% [markdown]
# First Floor Area

# %%
sns.scatterplot(x=rawDf['First_Floor_Area'], y=rawDf['Sale_Price'])
plt.xlabel("First Floor Area")
plt.ylabel("Sale Price")
plt.show()

# %% [markdown]
# There is a positive correlation between First Floor Area and Sale Price as with the increase in first floor area, sale price has increased and has a scattered range.

# %% [markdown]
# Total Basement Area

# %%
sns.scatterplot(x=rawDf['Total_Basement_Area'], y=rawDf['Sale_Price'])
plt.xlabel("Total Basement Area")
plt.ylabel("Sale Price")
plt.show()

# %% [markdown]
# There is a positive correlation between Total Basement Area and Sale Price as with the increase in Total Basement area, sale price has increased and has a scattered range.

# %% [markdown]
# Second Floor Area

# %%
sns.scatterplot(x=rawDf['Second_Floor_Area'], y=rawDf['Sale_Price'])
plt.xlabel("Second Floor Area")
plt.ylabel("Sale Price")
plt.show()

# %% [markdown]
# There is a positive correlation between Second Floor Area and Sale Price, but they are not highly correlated. It is because houses with no second floor have a high median sale price than houses with second floor varying between 500 and 1000 sq ft.

# %% [markdown]
# Low Quality Finished SF

# %%
sns.scatterplot(x=rawDf['LowQualFinSF'], y=rawDf['Sale_Price'])
plt.xlabel("Low Quality Finished Square Feet")
plt.ylabel("Sale Price")
plt.show()

# %% [markdown]
# There is no correlation between LowQualFinSF and Sale Price

# %% [markdown]
# Underground Full Bathroom

# %%
sns.barplot(x=rawDf['Underground_Full_Bathroom'], y=rawDf['Sale_Price'])
plt.xlabel("Underground Full Bathroom")
plt.ylabel("Sale Price")
plt.show()

# %% [markdown]
# Houses with 2 underground bathrooms are the most expensive ones.

# %% [markdown]
# There is a very low correlation between Underground Bathrooms and Sale Price

# %% [markdown]
# Full Bathroom Above Grade

# %%
sns.barplot(x=rawDf['Full_Bathroom_Above_Grade'], y=rawDf['Sale_Price'])
plt.xlabel("Full Bathrooms")
plt.ylabel("Sale Price")
plt.show()

# %% [markdown]
# Houses with 3 full bathrooms are the most expensive ones

# %% [markdown]
# No. of Bathrooms and Sale Price are positively correlated

# %% [markdown]
# Bedroom Above Grade

# %%
sns.barplot(x=rawDf['Bedroom_Above_Grade'], y=rawDf['Sale_Price'])
plt.xlabel("No. of Bedrooms")
plt.ylabel("Sale Price")
plt.show()

# %% [markdown]
# There is no correlation between No. of Bedrooms and Sale Price

# %% [markdown]
# Rooms Above Grade

# %%
sns.barplot(x=rawDf['Rooms_Above_Grade'], y=rawDf['Sale_Price'])
plt.xlabel("Total no. of rooms")
plt.ylabel("Sale Price")
plt.show()

# %%
# Sale Price increases with increasing number of rooms

# %% [markdown]
# Positive Correlation between Total no. of rooms and Sale price

# %% [markdown]
# Fireplaces

# %%
sns.barplot(x=rawDf['Fireplaces'], y=rawDf['Sale_Price'])
plt.xlabel("No. of Fireplaces")
plt.ylabel("Sale Price")
plt.show()

# %%
# Sale prices of house increases with increase in no. of fireplaces

# %% [markdown]
# Positive correlation between Fireplaces and Sale Price

# %% [markdown]
# Garage Built Year

# %%
sns.lineplot(x=rawDf['Garage_Built_Year'], y=rawDf['Sale_Price'])
plt.xlabel("Garage Built Year")
plt.ylabel("Sale Price")
plt.show()

# %%
# Houses with recently build garages have a higher sale price than others

# %% [markdown]
# Positive correlation between Garage Built Year and Sale Price

# %% [markdown]
# Garage Area

# %%
sns.scatterplot(x=rawDf['Garage_Area'], y=rawDf['Sale_Price'])
plt.xlabel("Garage Area")
plt.ylabel("Sale Price")
plt.show()

# %% [markdown]
# No correlation between Garage Area and Sale Price

# %% [markdown]
# Pool Area

# %%
sns.scatterplot(x=rawDf['Pool_Area'], y=rawDf['Sale_Price'])
plt.xlabel("Pool Area")
plt.ylabel("Sale Price")
plt.show()

# %% [markdown]
# No correlation between Pool Area and Sale Price

# %% [markdown]
# Miscellaneous Value

# %%
sns.scatterplot(x=rawDf['Miscellaneous_Value'], y=rawDf['Sale_Price'])
plt.xlabel("Miscellaneous Value")
plt.ylabel("Sale Price")
plt.show()

# %% [markdown]
# No correlation between Miscellaneous Value and Sale Price

# %% [markdown]
# Year Sold

# %%
sns.lineplot(x=rawDf['Year_Sold'], y=rawDf['Sale_Price'])
plt.xlabel("Year Sold")
plt.ylabel("Sale Price")
plt.show()

# %% [markdown]
# Negative correlation between Year Sold and Sale Price

# %% [markdown]
# # Outlier Detection and Correction

# %%
for i in rawDf.columns:
    if i!='Sale_Price':
        if rawDf[i].dtypes!='O':
            Q1 = np.quantile(rawDf[i],0.25)
            Q3 = np.quantile(rawDf[i],0.75)
            IQR = Q3-Q1
            LowerBound = Q1-1.5*IQR
            UpperBound = Q3+1.5*IQR
            rawDf[i]=np.where(rawDf[i]<LowerBound, LowerBound, rawDf[i])
            rawDf[i]=np.where(rawDf[i]>UpperBound, UpperBound, rawDf[i])

# %% [markdown]
# # Dummy Variables

# %%
fullDf = pd.get_dummies(rawDf)

# %%
fullDf.shape
# Out:
# (1459, 43)

# %% [markdown]
# # Splitting Data

# %%
from sklearn.model_selection import train_test_split

# %%
trainDf, testDf = train_test_split(fullDf, train_size=0.8, random_state=2410)

# %%
trainDf.shape
# Out:
# (1167, 43)

# %%
testDf.shape
# Out:
# (292, 43)

# %% [markdown]
# Splitting the data further into dependent and indepedent variables

# %%
trainX = trainDf.drop('Sale_Price', axis=1)

# %%
trainY = trainDf['Sale_Price']

# %%
testX = testDf.drop('Sale_Price', axis=1)

# %%
testY = testDf['Sale_Price']

# %% [markdown]
# # Model Building

# %%
from sklearn.linear_model import LinearRegression

# %%
M1 = LinearRegression().fit(trainX,trainY)

# %%
M1
# Out:
# LinearRegression()

# %% [markdown]
# Prediction

# %%
test_pred = M1.predict(testX)

# %% [markdown]
# Evaluation

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error

# %%
MS_Var = mean_squared_error(testY, test_pred)
MS_Var
# Out:
# 1288552576.3125856

# %%
RMSE_Error = np.sqrt(MS_Var)

# %%
RMSE_Error
# Out:
# 35896.414532827446

# %%
MAPE = mean_absolute_percentage_error(testY, test_pred)

# %%
MAPE
# Out:
# 0.1395824170605616

# %%
# 14% Error
